# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Conceptual

# %% [markdown]
# ---
# 1. Describe the null hypotheses to which the p-values given in Table 3.4
# correspond. Explain what conclusions you can draw based on these
# p-values. Your explanation should be phrased in terms of sales, TV,
# radio, and newspaper, rather than in terms of the coefficients of the
# linear model.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ---

# %% [markdown]
# So, here we have some linear regression model with predictors(TV, radio, newspaper) and response(Sales).
# Ans here we see some statistics. So, first of all, lets remind to oursefles - what is null hypotesis? Here this is a test,
# that consists of $H_0$ and $H_a$, where:
# - $H_0$ - the hypotesis, that all coefficients of a predicors($B_1$, $B_2$, $B_3$) are all equal zero, which means that corresponding
# predictors does not contain some useful info to our response: $B_1$ = $B_2$ = $B_3$ = 0
# - $H_a$ - at least one predictor has non-zero coefficient.
# This type of test is importat because before building some models, we want to know if our predictors has some influence on response.
#
# In order to reject or apporove null hypotesis, we compute t-statistic to each coefficient:
# $$t=\frac{\hat{\beta}_1-0}{\mathrm{SE}(\hat{\beta}_1)}$$
# and then, we get some p-value, which helps us to understand if coeffcient is non-zero. In general, if p < 0.05, then coefficent is non-zero.
#
# If we look at the table, we see that TV anf radio has very small p-value, while newspaper has quite huge - 0.8599.
# So, we can make assumption, that in this model - newspapper is not important and does not carry some useful info since the corresponding
# coefficient is approximately equal to zero.

# %% [markdown]
# ---
# 2. Carefully explain the differences between the KNN classifier and KNN
# regression methods
# ---

# %% [markdown]
# So, the main difference between KNN clasifier and KNN regression is that they have different goals.
#
# KNN classifier: this method is used in CLASSIFICATION tasks. The main idea is to take some K(number of neighbors), and
# the class for every new test point will be selected based on number of classes in the neighborhood:
# $$
# \Pr(Y = j \mid X = x_0) = \frac{1}{K} \sum_{i \in N_0} I(y_i = j)
# $$
# ,
# where for each value in neigborhood we indicate whether it 1 - belongs to some class 1 or 0 if not, and in result we get the propotion -
# the probability of new test point to be in class i
#
# KNN regression: this method is used for REGRESSION problems. The concept us the same: we find some k nearest neighbors, sum them, and
# their mean - new test point:
# $$
# \hat{f}(x_0)=\frac{1}{K}\sum_{x_i\in\mathcal{N}_0}y_i.
# $$

# %% [markdown]
# ----
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# ----

# %% [markdown]
# Predictors:
# - $X_1$ - GPA
# - $X_2$ - IQ
# - $X_3$ - Level (1 for College and 0 for High School)
# - $X_4$ - GPA X IQ
# - $X_5$ - GPA X Level
#
# Response: starting salary after graduation (in thousands
# of dollars)
#
# βˆ0 = 50, βˆ1 = 20, βˆ2 = 0.07, βˆ3 = 35, βˆ4 = 0.01, βˆ5 = −10

# %% [markdown]
# (a)
#
# i: So, $X_3$ is a categorical variable, where we have 1 if we have high college graduate and 0 otherwise if high school.
# And what we can say: when we have $X_3$ = 1, then the corresponding coefficent $B_3$ = 35, which means, that when GPA and IQ are fixed,
# college graduates for one unit earns:
#  $$
#  B_0 + B_3 * X_3 = 50 + 35 * 1 = 85
#  $$,
#  while high school:
#  $$
#  B_0 + B_3 * X_3 = 50 + 35 * 0 = 50
#  $$
#
# So, this statement is false

# %% [markdown]
# ii: This is true

# %% [markdown]
# iii: in order to approve or reject this, we have predictor: GPA x Level, which can help us to see, if the interaction of level and GPA has some significant influence on response. $B_5$ = -10, which means that for college students, with GPA increasing, salary is not, while for high school higer GPA means higer salary:
#
# High School (Level = 0):
# $$\hat{Y}_{HS} = 50 + 20 \cdot GPA + 0.07 \cdot IQ + 35 \cdot 0 + 0.01 \cdot (GPA \cdot IQ) + (-10) \cdot (GPA \cdot 0)$$
# $$
# \hat{Y}_{HS} = 50 + 20 \cdot GPA + 0.07 \cdot IQ + 0.01 \cdot GPA \cdot IQ$$
# College (Level = 1):
# $$\hat{Y}_{C} = 50 + 20 \cdot GPA + 0.07 \cdot IQ + 35 \cdot 1 + 0.01 \cdot (GPA \cdot IQ) + (-10) \cdot (GPA \cdot 1)$$
# $$
# \hat{Y}_{C} = 50 + 35 + (20 - 10)GPA + 0.07IQ + 0.01GPA \cdot IQ$$
# $$\hat{Y}_{C} = 85 + 10 \cdot GPA + 0.07IQ + 0.01GPA \cdot IQ$$
#
# - For small GPA ≈ 1-2:
# $\hat{Y}_{HS} = 50 + 20 * 1 = 70$
# $\hat{Y}_{C} = 85 + 10 * 1 = 95$
#
# → College earns more.
#
# - For high GPA = 10:
# $\hat{Y}_{HS} = 50 + 20 * 10 = 250$
# $\hat{Y}_{C} = 85 + 10 * 10 = 185$
#
# → High School earns more.
#
#
# So, we see that interaction Level X GPA has negative influence on college graduate`s salaries. For small GPA college students earns more. But for high --> school graduates.
#
# This statement is false

# %% [markdown]
# iv: This is true

# %% [markdown]
# (b)
#
# $X_1$ = 4
#
# $X_2$ = 110
#
# $X_3$ = 1
#
# $X_4$ = 4 * 110
#
# $X_1$ = 4 * 1
#
# $$
# Y=\beta_0+\beta_1\mathrm{GPA}+\beta_2\mathrm{IQ}+\beta_3\mathrm{Level}+\beta_4(\mathrm{GPA}\cdot\mathrm{IQ})+\beta_5(\mathrm{GPA}\cdot\mathrm{Level})
# $$
# $$
# salary = 50 + 20 * 4 + 0.07 * 110 + 35 * 1 + 0.01 * 4 * 110 - 10 * 4 * 1 = 137.1
# $$

# %% [markdown]
# (c)
#
# I can suppose that this is false, because no matter how big or small $B_i$ coefficient, we can say that some predictor is useless only based on p-value

# %% [markdown]
# ---
#
# ![image.png](attachment:image.png)
#
# ---

# %% [markdown]
# $$
# Y = β0 + β_1X + β_2X^{2} + β_3X^{3} + e
# $$

# %% [markdown]
# (a)
#
# Suppose true relationship is linear ==> $Y = β0 + β_1X + e$
#
# So, we need to say which training RSS will be lower: in linear or cubi regression?
#
# Since true relationship is linear, linear model will be quite precise, cubic regression is some flexible non-linear model, which can follow some noise and have huge variance, but if we talk about TRAINING RSS, this model can show good results, because it can be overfitted and make some "fake" assumption that it is precise. So, cubic regression can be a little more precise at traning data.

# %% [markdown]
# (b)
#
# If we talk about TEST RSS, here linear model will show a little higher RSS result, but there will not some big differnces between test and training since true relationship is linear. For training anf test linear regression will show goof results. But, if we talking about flexible model like cubic regression, which can easily follow some noise, and be overfitted,i would say that the test RSS will be much bigger than training anf than in linear model.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (c)
#
# If our true relationshio is non-linear, but we do not know, how far, i think that cubic regression model will be better choice,
# since it not some very flexible model for example if true relationship is also not very non-linear, but even if true relationhship is very flexible non-linear - cubic will be better choice rather than linear model again because it is more approximate to flexible,
# and can handle some difficul patterns which linear model can not do. So, traning RSS will be smaller in cubic regression.

# %% [markdown]
# (d)
#
# This is where caution is needed:
#
# If the true relationship is non-linear but not too extreme, cubic regression may generalize better → lower test RSS than linear.
#
# If the true relationship is very complicated, cubic regression may overfit the training data → higher test RSS.
#
# The key: we don’t know how far the true relationship is from linear, so we cannot be certain that cubic regression will always have lower test RSS.

# %% [markdown]
# ### Applied

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.stats.outliers_influence \
import variance_inflation_factor as VIF
from statsmodels.stats.anova import anova_lm
from ISLP import load_data
from ISLP.models import (ModelSpec as MS,
summarize,
poly)

# %%
auto = load_data("Auto")

auto.head()
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0         130    3504
# buick skylark 320          15.0          8         350.0         165    3693
# plymouth satellite         18.0          8         318.0         150    3436
# amc rebel sst              16.0          8         304.0         150    3433
# ford torino                17.0          8         302.0         140    3449
#
#                            acceleration  year  origin
# name
# chevrolet chevelle malibu          12.0    70       1
# buick skylark 320                  11.5    70       1
# plymouth satellite                 11.0    70       1
# amc rebel sst                      12.0    70       1
# ford torino                        10.5    70       1

# %%
horsepower = auto["horsepower"]
mpg = auto["mpg"]

X = sm.tools.add_constant(horsepower)
X.head()
# Out:
#                            const  horsepower
# name
# chevrolet chevelle malibu    1.0         130
# buick skylark 320            1.0         165
# plymouth satellite           1.0         150
# amc rebel sst                1.0         150
# ford torino                  1.0         140

# %%
y = mpg

model = sm.OLS(y, X)  #creates linear regression object, knows the data but have not computed anything
results1 = model.fit()  #computes orduinary least squares to minimize RSS, return all stats
summarize(results1)
# Out:
#                coef  std err       t  P>|t|
# const       39.9359    0.717  55.660    0.0
# horsepower  -0.1578    0.006 -24.489    0.0

# %%
results1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.605
# Method:                 Least Squares   F-statistic:                     599.7
# Date:                Sun, 21 Sep 2025   Prob (F-statistic):           7.03e-81
# Time:                        09:44:10   Log-Likelihood:                -1178.7
# No. Observations:                 392   AIC:                             2361.
# Df Residuals:                     390   BIC:                             2369.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         39.9359      0.717     55.660      0.000      38.525      41.347
# ...

# %% [markdown]
# So, above we see results of fitting our linear regression model with one predictor - horsepower.
#
# i. Is there a relationship between the predictor and the response?
#   yeah, we can say that because, if we look at p-value which is 0 we can easily reject null hypotesis,
#   and say that the corresponding coefficient of horsepower predictor is non-zero.
#
# ii. How strong is the relationship between the predictor and
# the response?
#   we can say that relationship is quite string based on t-statistics and p-value
#
# iii. Is the relationship between the predictor and the response
# positive or negative?
#   the relationship is negative - -0.1578, so we can say with horsepower increasing, the mpg is decreasing

# %%
prediction = results1.get_prediction(pd.DataFrame({"const": [1.0], "horsepower": [98]}))
prediction.predicted_mean
# Out:
# array([24.46707715])

# %%
prediction.conf_int(alpha=0.05)
# Out:
# array([[23.97307896, 24.96107534]])

# %%
prediction.conf_int(alpha=0.05, obs=True)
# Out:
# array([[14.80939607, 34.12475823]])

# %%
ax = auto.plot.scatter("horsepower", "mpg")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 2
#       1 ax = auto.plot.scatter("horsepower", "mpg")
# ----> 2 ax.axline()
#
# TypeError: Axes.axline() missing 1 required positional argument: 'xy1'

# %%
def abline(ax, a, b, *args, **kwargs):
  xlim = ax.get_xlim()
  ylim = [a * xlim[0] + b, a * xlim[1] + b]
  ax.plot(xlim, ylim, *args, **kwargs)

# %%
ax = auto.plot.scatter("horsepower", "mpg")
abline(
  ax,
  results1.params[1],
  results1.params[0],
  "r--",
  linewidth=3
)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15956\1536324752.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results1.params[1],
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15956\1536324752.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results1.params[0],

# %% [markdown]
# So, here we see least squares line. From plot we can see, that data is a little bit non-linear, and some more
# flexible model(polynimial regression) would better fit data

# %%
ax = plt.subplots(figsize=(8, 8))[1]
ax.scatter(results1.fittedvalues, results1.resid)
ax.set_xlabel("Fitted values")
ax.set_ylabel("Residuals")
ax.axhline(0, c="k", ls="--", label="True values")

ax.legend()

# %% [markdown]
# As i said earlier, polynomial model would better fit this data, because we see some non-linear trend: data starts from the top, decreases and increases again, some u-shape line would be the best choice

# %%
results1.fittedvalues
# Out:
# name
# chevrolet chevelle malibu    19.416046
# buick skylark 320            13.891480
# plymouth satellite           16.259151
# amc rebel sst                16.259151
# ford torino                  17.837598
#                                ...
# ford mustang gl              26.361214
# vw pickup                    31.727935
# dodge rampage                26.676903
# ford ranger                  27.466127
# chevy s-10                   26.992593
# Length: 392, dtype: float64

# %%
mpg
# Out:
# name
# chevrolet chevelle malibu    18.0
# buick skylark 320            15.0
# plymouth satellite           18.0
# amc rebel sst                16.0
# ford torino                  17.0
#                              ...
# ford mustang gl              27.0
# vw pickup                    44.0
# dodge rampage                32.0
# ford ranger                  28.0
# chevy s-10                   31.0
# Name: mpg, Length: 392, dtype: float64

# %%
results1.resid
# Out:
# name
# chevrolet chevelle malibu    -1.416046
# buick skylark 320             1.108520
# plymouth satellite            1.740849
# amc rebel sst                -0.259151
# ford torino                  -0.837598
#                                ...
# ford mustang gl               0.638786
# vw pickup                    12.272065
# dodge rampage                 5.323097
# ford ranger                   0.533873
# chevy s-10                    4.007407
# Length: 392, dtype: float64

# %%
results1.resid.max()
# Out:
# 16.924046646817015

# %%
X = MS([poly("horsepower", degree=2)]).fit_transform(auto)
X
# Out:
#                            intercept  poly(horsepower, degree=2)[0]  \
# name
# chevrolet chevelle malibu        1.0                       0.033544
# buick skylark 320                1.0                       0.079529
# plymouth satellite               1.0                       0.059821
# amc rebel sst                    1.0                       0.059821
# ford torino                      1.0                       0.046682
# ...                              ...                            ...
# ford mustang gl                  1.0                      -0.024266
# vw pickup                        1.0                      -0.068938
# dodge rampage                    1.0                      -0.026894
# ford ranger                      1.0                      -0.033463
# chevy s-10                       1.0                      -0.029522
#
#                            poly(horsepower, degree=2)[1]
# name
# chevrolet chevelle malibu                      -0.052723
# ...

# %%
model = sm.OLS(y, X)
results2 = model.fit()
summarize(results2)
# Out:
#                                    coef  std err        t  P>|t|
# intercept                       23.4459    0.221  106.130    0.0
# poly(horsepower, degree=2)[0] -120.1377    4.374  -27.467    0.0
# poly(horsepower, degree=2)[1]   44.0895    4.374   10.080    0.0

# %%
results2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.688
# Model:                            OLS   Adj. R-squared:                  0.686
# Method:                 Least Squares   F-statistic:                     428.0
# Date:                Sun, 21 Sep 2025   Prob (F-statistic):           5.40e-99
# Time:                        10:16:08   Log-Likelihood:                -1133.2
# No. Observations:                 392   AIC:                             2272.
# Df Residuals:                     389   BIC:                             2284.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...

# %%
coeffs = results2.params[::-1].values
coeffs
# Out:
# array([  44.08952778, -120.13774427,   23.44591837])

# %%
# create smooth x
x_raw = np.linspace(x_data.min(), x_data.max(), 300).reshape(-1,1)

# transform using the same scaler + poly pipeline
X_smooth = MS([poly("horsepower", degree=2)]).fit(auto).transform(pd.DataFrame({"horsepower": x_raw.flatten()}))

# predict y using fitted coefficients
y_smooth = results2.predict(X_smooth)

# plot
ax = auto.plot.scatter("horsepower", "mpg")
ax.plot(x_raw, y_smooth, color="red", label="Poly deg2")
ax.legend()

# %% [markdown]
# We see, that polynomial model fits the data much better, and this also we can see in stats, for example:
#
# Linear: $R^{2}$ = 0.606
#
# Poly: $R^{2}$ = 0.688
#
# So, polynomial model better explains the vaiablity in data

# %%
X = MS([poly("horsepower", degree=10)]).fit_transform(auto)
y = mpg

model = sm.OLS(y, X)
results3 = model.fit()
summarize(results3)
# Out:
#                                     coef  std err        t  P>|t|
# intercept                        23.4459    0.217  107.840  0.000
# poly(horsepower, degree=10)[0] -120.1377    4.305  -27.909  0.000
# poly(horsepower, degree=10)[1]   44.0895    4.305   10.242  0.000
# poly(horsepower, degree=10)[2]   -3.9488    4.305   -0.917  0.360
# poly(horsepower, degree=10)[3]   -5.1878    4.305   -1.205  0.229
# poly(horsepower, degree=10)[4]   13.2722    4.305    3.083  0.002
# poly(horsepower, degree=10)[5]   -8.5462    4.305   -1.985  0.048
# poly(horsepower, degree=10)[6]    7.9806    4.305    1.854  0.065
# poly(horsepower, degree=10)[7]    2.1727    4.305    0.505  0.614
# poly(horsepower, degree=10)[8]   -3.9182    4.305   -0.910  0.363
# poly(horsepower, degree=10)[9]   -2.6146    4.305   -0.607  0.544

# %% [markdown]
# We see, that p-value in many predictors are huge which tells that corresponding coeeficients are close to zero

# %%
results3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.704
# Model:                            OLS   Adj. R-squared:                  0.696
# Method:                 Least Squares   F-statistic:                     90.45
# Date:                Sun, 21 Sep 2025   Prob (F-statistic):           3.51e-94
# Time:                        10:50:09   Log-Likelihood:                -1122.8
# No. Observations:                 392   AIC:                             2268.
# Df Residuals:                     381   BIC:                             2311.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Also we see that with using such complicated model, the $R^{2}$ increased to 0.704

# %%
ax = plt.subplots(figsize=(8, 8))[1]
ax.scatter(results3.fittedvalues, results3.resid)
ax.axhline(0, c="k")

# %%
auto.head()
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0         130    3504
# buick skylark 320          15.0          8         350.0         165    3693
# plymouth satellite         18.0          8         318.0         150    3436
# amc rebel sst              16.0          8         304.0         150    3433
# ford torino                17.0          8         302.0         140    3449
#
#                            acceleration  year  origin
# name
# chevrolet chevelle malibu          12.0    70       1
# buick skylark 320                  11.5    70       1
# plymouth satellite                 11.0    70       1
# amc rebel sst                      12.0    70       1
# ford torino                        10.5    70       1

# %%
pd.plotting.scatter_matrix(auto, figsize=(10, 10))

plt.tight_layout()

# %%
auto.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# year          0.580541  -0.345647     -0.369855   -0.416361 -0.309120
# origin        0.565209  -0.568932     -0.614535   -0.455171 -0.585005
#
#               acceleration      year    origin
# mpg               0.423329  0.580541  0.565209
# cylinders        -0.504683 -0.345647 -0.568932
# displacement     -0.543800 -0.369855 -0.614535
# horsepower       -0.689196 -0.416361 -0.455171
# weight           -0.416839 -0.309120 -0.585005
# acceleration      1.000000  0.290316  0.212746
# ...

# %%
X = auto[auto.columns.drop("mpg")]
X = sm.tools.add_constant(X)
y = auto["mpg"]

model = sm.OLS(y, X)
results4 = model.fit()

print(summarize(results4))
print(results4.summary())
# Out:
#                  coef  std err       t  P>|t|
# const        -17.2184    4.644  -3.707  0.000
# cylinders     -0.4934    0.323  -1.526  0.128
# displacement   0.0199    0.008   2.647  0.008
# horsepower    -0.0170    0.014  -1.230  0.220
# weight        -0.0065    0.001  -9.929  0.000
# acceleration   0.0806    0.099   0.815  0.415
# year           0.7508    0.051  14.729  0.000
# origin         1.4261    0.278   5.127  0.000
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.818
# Method:                 Least Squares   F-statistic:                     252.4
# Date:                Sun, 21 Sep 2025   Prob (F-statistic):          2.04e-139
# Time:                        11:40:57   Log-Likelihood:                -1023.5
# No. Observations:                 392   AIC:                             2063.
# ...

# %%
anova_lm(results1, results4)
# Out:
#    df_resid          ssr  df_diff      ss_diff          F        Pr(>F)
# 0     390.0  9385.915872      0.0          NaN        NaN           NaN
# 1     384.0  4252.212530      6.0  5133.703341  77.267308  5.376746e-63

# %% [markdown]
# We can suppose that we have relationship between reposnse and predictors since the p-value = 5.376746e-63 is
# extremely small.
#
# Also $R^{2}$ is 0.818 which is high number and it tells us that model explains variance not bad.

# %% [markdown]
# Which predictors appear to have a statistically significant
# relationship to the response?
#
# From table above, looking at p-value, we can say that such predictors like: displacement, year, weight and origin have a statistically significant relationship to the response, while acceleration has a huge p-value and we can think about dropping this column.

# %% [markdown]
# What does the coefficient for the year variable suggest?
#
# Corresponding coefficient to year: 0.7508. It tells that the mpg is bigger when the car is newer, or to be more precise: with increasing year by one, mpg increases by 0.7508

# %%
import seaborn as sns

_, ax = plt.subplots(figsize=(8, 8))
ax = sns.residplot(
  x=results4.fittedvalues,
  y=y,
  lowess=True,
  scatter_kws={"alpha": 0.5},
  line_kws={"color": "red", "lw": 1, "alpha": 0.8}
)
ax.set_xlabel("Fitted values")
ax.set_ylabel("Residuals")
# Out:
# Text(0, 0.5, 'Residuals')

# %% [markdown]
# Here we see, that we still have non-liner trend, and red line suggests shows to us this, though the residuals values are smaller.

# %%
infl = results4.get_influence()
#get_influence() returns an Influence object for your fitted model.
#It allows you to compute diagnostic measures like:
#  -Leverage (hat_matrix_diag)
#  -Studentized residuals
#  -Cook’s distance
#These metrics help detect outliers and influential points in regression.

# %%
h_avg = (X.shape[1] + 1) / X.shape[0]
h_avg
# Out:
# 0.02295918367346939

# %%
_, ax = plt.subplots(figsize=(8, 8))
ax.scatter(np.arange(X.shape[0]), infl.hat_matrix_diag, marker="o",
           facecolors='none', edgecolors='black', linewidths=0.5)
ax.axhline(h_avg, ls="--", c="r", alpha=0.6, label="Average leverage")
ax.set_xlabel("Index")
ax.set_ylabel("Leverage")
np.argmax(infl.hat_matrix_diag)

plt.legend()

# %%
np.argmax(infl.hat_matrix_diag)
# Out:
# 13

# %% [markdown]
# With the help of graph above, we can see that we have some points with high leverage(points with x that differs a lot from x mean among all points)

# %%
X.iloc[13]
# Out:
# const              1.0
# cylinders          8.0
# displacement     455.0
# horsepower       225.0
# weight          3086.0
# acceleration      10.0
# year              70.0
# origin             1.0
# Name: buick estate wagon (sw), dtype: float64

# %% [markdown]
# In order to understand: if point is high leverage, its high leverage have to be in 3 times bigger than average

# %%
infl.hat_matrix_diag[13] / h_avg
# Out:
# 8.27176125802827

# %%
#all points with high leverage > 3

high_leverage_points = (infl.hat_matrix_diag / h_avg) > 3
np.where(high_leverage_points)[0]
# Out:
# array([13, 28], dtype=int64)
